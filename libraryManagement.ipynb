# %%
class Library:

    def __init__(self):
        self.file_name = "books.txt"
        self.file = open(self.file_name, "a+")

    def __del__(self):
        self.file.close()

    def list_books(self):

        self.file.seek(0)

        ### Create a list of books by separating each line with a comma
        books = [book.split(',') for book in self.file.read().splitlines()]
        for title, author, release_year, num_pages in books:
            print(f"Title: {title}, Author: {author}, Release Year: {release_year}, Pages: {num_pages}")

    def add_book(self):

        ### Get book information from user
        title = input("Enter book title: ")
        author = input("Enter author: ")
        release_year = int(input("Enter release year: "))
        num_pages = int(input("Enter number of pages: "))

        ### Add book information to file
        book_info = f"{title},{author},{release_year},{num_pages}\n"
        self.file.write(book_info)

        print(f"Book '{title}'.")

    def remove_book(self):

        ### Get the name of the book to delete
        title = input("Enter the title of the book to remove: ")
        self.file.seek(0)

        books = [book for book in self.file.readlines() if title not in book]

        self.file.seek(0)
        self.file.truncate()
        self.file.writelines(books)

        print(f"Book '{title}' removed.")



lib = Library() # Create an object

while True:     # Create a MENU

    print("*** MENU ***")
    print("1) List Books")
    print("2) Add Book")
    print("3) Remove Book")
    print("E) Exit")

    choice = input("Enter your choice (1/2/3/E): ")

    if choice == "1":
        lib.list_books()
    elif choice == "2":
        lib.add_book()
    elif choice == "3":
        lib.remove_book()
    elif choice == "E":
        print("Exit")
        break
    else:
        print("Invalid choice. Please enter 1 , 2 , 3 or E....")
# Out:
# *** MENU ***
# 1) List Books
# 2) Add Book
# 3) Remove Book
# E) Exit
# Enter your choice (1/2/3/E): 1
# Title: 1984, Author: George Orwell, Release Year: 1949, Pages: 352
# Title: Piraye, Author: Canan Tan, Release Year: 2003, Pages: 280
# Title: En Son Yürekler Ölür, Author: Canan Tan, Release Year: 2009, Pages: 408
# Title: Dört Anlaşma: Toltek Bilgelik Kitabı, Author: Don Miguel Ruiz, Release Year: 1997, Pages: 122
# Title: Operadaki Hayalet, Author: Gaston Leroux, Release Year: 1909, Pages: 360
# Title: Alacakaranlık, Author: Stephenie Meyer, Release Year: 2005, Pages: 407
# Title: Şeker Portakalı, Author: José Mauro de Vasconcelos, Release Year: 1968, Pages: 200
# *** MENU ***
# 1) List Books
# 2) Add Book
# 3) Remove Book
# E) Exit
# Enter your choice (1/2/3/E): 3
# Enter the title of the book to remove: Şeker Portakalı
# Book 'Şeker Portakalı' removed.
# *** MENU ***
# 1) List Books
# 2) Add Book
# 3) Remove Book
# E) Exit
# Enter your choice (1/2/3/E): 1
# Title: 1984, Author: George Orwell, Release Year: 1949, Pages: 352
# Title: Piraye, Author: Canan Tan, Release Year: 2003, Pages: 280
# Title: En Son Yürekler Ölür, Author: Canan Tan, Release Year: 2009, Pages: 408
# Title: Dört Anlaşma: Toltek Bilgelik Kitabı, Author: Don Miguel Ruiz, Release Year: 1997, Pages: 122
# Title: Operadaki Hayalet, Author: Gaston Leroux, Release Year: 1909, Pages: 360
# Title: Alacakaranlık, Author: Stephenie Meyer, Release Year: 2005, Pages: 407
# *** MENU ***
# 1) List Books
# 2) Add Book
# 3) Remove Book
# E) Exit
# Enter your choice (1/2/3/E): 2
# Enter book title: Şeker Portakalı
# Enter author: José Mauro de Vasconcelos
# Enter release year: 1968
# Enter number of pages: 200
# Book 'Şeker Portakalı'.
# *** MENU ***
# 1) List Books
# 2) Add Book
# 3) Remove Book
# E) Exit
# Enter your choice (1/2/3/E): E
# Exit
